# %%
import torch
import keras
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd
import tensorflow as tf
from torchvision import models, transforms
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import torchvision
from functools import partial
import keras
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from PIL import Image

# %%
PATH_TO_RAVDESS = Path.cwd()/"ravdess"
PATH_RAVDESS_TRAIN = PATH_TO_RAVDESS/"train"
bs_train = 1440

# %%
class PrecomputedRavdess(Dataset):
    def __init__(self,path,dpi=50, img_transforms=None):
        files = Path(path).glob('{}{}*.wav.png'.format(path.name, dpi))
        self.items = [(f,int(f.name.split("-")[2].replace(".wav.png",""))) for f in files]
        self.length = len(self.items)
        if img_transforms == None:
            self.img_transforms = transforms.Compose([transforms.ToTensor()])
        else:
            self.img_transforms = img_transforms
    
    def __getitem__(self, index):
        filename, label = self.items[index]
        img = Image.open(filename).convert('RGB')
        return (self.img_transforms(img), label)
            
    def __len__(self):
        return self.length

# %%
ravdess_train = PrecomputedRavdess(PATH_RAVDESS_TRAIN,
                                  img_transforms=transforms.Compose([
                                      transforms.ToTensor(),
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                          std=[0.229, 0.224, 0.225])])
)

# %%
ravdess_train_loader = torch.utils.data.DataLoader(ravdess_train,bs_train, shuffle=True)
spectogram = torch.utils.data.DataLoader(ravdess_train,32,shuffle=True )

# %%
images, labels = next(iter(ravdess_train_loader))  
img, label = next(iter(spectogram))  
def imshow(img):
     img = img / 2 + 0.5
     npimg = img.numpy()
     plt.imshow(np.transpose(npimg, (1, 2, 0)))
     plt.show()
print('Validationslabel:',label)
imshow(torchvision.utils.make_grid(img)/3)
# Out:
# Validationslabel: tensor([5, 4, 3, 5, 7, 6, 3, 5, 7, 6, 6, 6, 8, 2, 4, 7, 7, 8, 2, 4, 2, 5, 4, 4,
#         5, 8, 7, 2, 2, 2, 2, 4])

# %%
labels.shape
# Out:
# torch.Size([1161])

# %%
# Modelskonfiguration
batch_size = 32
img_width, img_height, img_num_channels = 3,200,300
loss_function = sparse_categorical_crossentropy
no_classes = 9
optimizer = Adam()
verbosity = 1
input_shape = (img_width, img_height, img_num_channels)

# %%
DefaultConv2D = partial(keras.layers.Conv2D, kernel_size=3, strides=1,
                        padding="SAME", use_bias=False)

class ResidualUnit(keras.layers.Layer):
    def __init__(self, filters, strides=1, activation="relu", **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.main_layers = [
            DefaultConv2D(filters, strides=strides),
            keras.layers.BatchNormalization(),
            self.activation,
            DefaultConv2D(filters),
            keras.layers.BatchNormalization()]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConv2D(filters, kernel_size=1, strides=strides),
                keras.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
model = keras.models.Sequential()
model.add(DefaultConv2D(64, kernel_size=3, strides=1,
                        input_shape= input_shape ))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Activation("relu"))
model.add(keras.layers.MaxPool2D(pool_size=3, strides=2, padding="SAME"))
prev_filters = 8
#for filters in [64] * 3 + [128] * 4 + [256] * 6 + [512] * 3: 
for filters in [64] * 1 + [128] * 1 + [256] * 2: 
    strides = 1 if filters == prev_filters else 2
    model.add(ResidualUnit(filters, strides=strides))
    prev_filters = filters
model.add(keras.layers.GlobalAvgPool2D())
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(no_classes, activation="softmax"))

# %%
images = (tf.cast(images, tf.float32) / 255).numpy()
labels = labels.numpy()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 3, 200, 64)        172800
# _________________________________________________________________
# batch_normalization (BatchNo (None, 3, 200, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 3, 200, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 2, 100, 64)        0
# _________________________________________________________________
# residual_unit (ResidualUnit) (None, 1, 50, 64)         78592
# _________________________________________________________________
# residual_unit_1 (ResidualUni (None, 1, 25, 128)        230912
# _________________________________________________________________
# residual_unit_2 (ResidualUni (None, 1, 13, 256)        920576
# _________________________________________________________________
# residual_unit_3 (ResidualUni (None, 1, 13, 256)        1181696
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 9)                 2313
# =================================================================
# Total params: 2,587,145
# Trainable params: 2,583,305
# Non-trainable params: 3,840
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Nadam(lr=1e-3)
model.compile(loss=loss_function,
              optimizer=optimizer,  metrics=['accuracy'])

# %%
history = model.fit(images, labels,
            batch_size=batch_size,
            epochs=100,        
            verbose=verbosity,
            validation_split = 0.2)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 14s 394ms/step - loss: 2.2494 - accuracy: 0.1949 - val_loss: 2.1417 - val_accuracy: 0.1502
# Epoch 2/100
# 29/29 [==============================] - 10s 344ms/step - loss: 1.5923 - accuracy: 0.3914 - val_loss: 2.1602 - val_accuracy: 0.1545
# Epoch 3/100
# 29/29 [==============================] - 10s 354ms/step - loss: 1.2899 - accuracy: 0.5295 - val_loss: 2.3106 - val_accuracy: 0.1502
# Epoch 4/100
# 29/29 [==============================] - 10s 359ms/step - loss: 1.1152 - accuracy: 0.5944 - val_loss: 3.1039 - val_accuracy: 0.1502
# Epoch 5/100
# 29/29 [==============================] - 11s 382ms/step - loss: 0.9162 - accuracy: 0.6667 - val_loss: 2.7258 - val_accuracy: 0.1502
# Epoch 6/100
# 29/29 [==============================] - 10s 348ms/step - loss: 0.8383 - accuracy: 0.6794 - val_loss: 3.1784 - val_accuracy: 0.1631
# Epoch 7/100
# 29/29 [==============================] - 10s 345ms/step - loss: 0.6149 - accuracy: 0.7998 - val_loss: 5.6535 - val_accuracy: 0.1288
# Epoch 8/100
# 29/29 [==============================] - 10s 344ms/step - loss: 0.5047 - accuracy: 0.8312 - val_loss: 3.8891 - val_accuracy: 0.1288
# Epoch 9/100
# 29/29 [==============================] - 10s 345ms/step - loss: 0.4396 - accuracy: 0.8385 - val_loss: 9.0050 - val_accuracy: 0.1288
# Epoch 10/100
# 29/29 [==============================] - 10s 344ms/step - loss: 0.2779 - accuracy: 0.9132 - val_loss: 10.2657 - val_accuracy: 0.1288
# Epoch 11/100
# 29/29 [==============================] - 10s 344ms/step - loss: 0.1662 - accuracy: 0.9488 - val_loss: 13.1617 - val_accuracy: 0.1288
# Epoch 12/100
# 29/29 [==============================] - 10s 346ms/step - loss: 0.1727 - accuracy: 0.9591 - val_loss: 8.1931 - val_accuracy: 0.1288
# Epoch 13/100
# 29/29 [==============================] - 10s 344ms/step - loss: 0.1666 - accuracy: 0.9434 - val_loss: 13.5793 - val_accuracy: 0.1288
# Epoch 14/100
# 29/29 [==============================] - 10s 346ms/step - loss: 0.1129 - accuracy: 0.9639 - val_loss: 15.8796 - val_accuracy: 0.1288
# Epoch 15/100
# 29/29 [==============================] - 10s 348ms/step - loss: 0.1160 - accuracy: 0.9656 - val_loss: 8.8042 - val_accuracy: 0.1288
# Epoch 16/100
# 29/29 [==============================] - 10s 348ms/step - loss: 0.0626 - accuracy: 0.9847 - val_loss: 17.6514 - val_accuracy: 0.1288
# Epoch 17/100
# 29/29 [==============================] - 10s 346ms/step - loss: 0.0558 - accuracy: 0.9784 - val_loss: 18.6773 - val_accuracy: 0.1288
# Epoch 18/100
# 29/29 [==============================] - 10s 346ms/step - loss: 0.0729 - accuracy: 0.9810 - val_loss: 10.2985 - val_accuracy: 0.1502
# Epoch 19/100
# 29/29 [==============================] - 10s 349ms/step - loss: 0.0694 - accuracy: 0.9814 - val_loss: 4.7151 - val_accuracy: 0.3219
# Epoch 20/100
# 29/29 [==============================] - 10s 344ms/step - loss: 0.1116 - accuracy: 0.9626 - val_loss: 11.3389 - val_accuracy: 0.1674
# Epoch 21/100
# 29/29 [==============================] - 10s 350ms/step - loss: 0.1308 - accuracy: 0.9413 - val_loss: 3.4839 - val_accuracy: 0.3648
# Epoch 22/100
# 29/29 [==============================] - 10s 347ms/step - loss: 0.1708 - accuracy: 0.9378 - val_loss: 4.3344 - val_accuracy: 0.3691
# Epoch 23/100
# 29/29 [==============================] - 10s 346ms/step - loss: 0.0932 - accuracy: 0.9713 - val_loss: 6.1617 - val_accuracy: 0.2876
# Epoch 24/100
# 29/29 [==============================] - 10s 352ms/step - loss: 0.0486 - accuracy: 0.9902 - val_loss: 4.8961 - val_accuracy: 0.3262
# Epoch 25/100
# 29/29 [==============================] - 11s 367ms/step - loss: 0.0283 - accuracy: 0.9951 - val_loss: 4.0277 - val_accuracy: 0.4163
# Epoch 26/100
# 29/29 [==============================] - 10s 358ms/step - loss: 0.0362 - accuracy: 0.9849 - val_loss: 3.1040 - val_accuracy: 0.4077
# Epoch 27/100
# 29/29 [==============================] - 11s 367ms/step - loss: 0.0429 - accuracy: 0.9845 - val_loss: 3.9025 - val_accuracy: 0.4249
# Epoch 28/100
# 29/29 [==============================] - 11s 366ms/step - loss: 0.0134 - accuracy: 0.9982 - val_loss: 2.7334 - val_accuracy: 0.4850
# Epoch 29/100
# 29/29 [==============================] - 10s 351ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 3.5309 - val_accuracy: 0.4506
# Epoch 30/100
# 29/29 [==============================] - 10s 344ms/step - loss: 0.0156 - accuracy: 0.9999 - val_loss: 2.5899 - val_accuracy: 0.5107
# Epoch 31/100
# 29/29 [==============================] - 10s 348ms/step - loss: 0.0287 - accuracy: 0.9955 - val_loss: 1.7192 - val_accuracy: 0.6009
# Epoch 32/100
# 29/29 [==============================] - 10s 349ms/step - loss: 0.0619 - accuracy: 0.9772 - val_loss: 7.7507 - val_accuracy: 0.1974
# Epoch 33/100
# 29/29 [==============================] - 10s 349ms/step - loss: 0.1217 - accuracy: 0.9634 - val_loss: 7.8822 - val_accuracy: 0.2790
# Epoch 34/100
# 29/29 [==============================] - 10s 347ms/step - loss: 0.0661 - accuracy: 0.9789 - val_loss: 4.9532 - val_accuracy: 0.2833
# Epoch 35/100
# 29/29 [==============================] - 10s 349ms/step - loss: 0.0386 - accuracy: 0.9870 - val_loss: 3.6459 - val_accuracy: 0.3991
# Epoch 36/100
# 29/29 [==============================] - 10s 345ms/step - loss: 0.0230 - accuracy: 0.9955 - val_loss: 3.0721 - val_accuracy: 0.4506
# Epoch 37/100
# 29/29 [==============================] - 10s 344ms/step - loss: 0.0360 - accuracy: 0.9825 - val_loss: 2.6179 - val_accuracy: 0.4635
# Epoch 38/100
# 29/29 [==============================] - 10s 347ms/step - loss: 0.0269 - accuracy: 0.9877 - val_loss: 3.2175 - val_accuracy: 0.5451
# Epoch 39/100
# 29/29 [==============================] - 10s 348ms/step - loss: 0.0179 - accuracy: 0.9956 - val_loss: 3.4933 - val_accuracy: 0.4335
# Epoch 40/100
# 29/29 [==============================] - 10s 355ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.7146 - val_accuracy: 0.5150
# Epoch 41/100
# 29/29 [==============================] - 10s 350ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.2135 - val_accuracy: 0.5966
# Epoch 42/100
# 29/29 [==============================] - 10s 348ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.7931 - val_accuracy: 0.6180
# Epoch 43/100
# 29/29 [==============================] - 10s 348ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.6357 - val_accuracy: 0.6223
# Epoch 44/100
# 29/29 [==============================] - 10s 348ms/step - loss: 7.4852e-04 - accuracy: 1.0000 - val_loss: 1.5088 - val_accuracy: 0.6524
# Epoch 45/100
# 29/29 [==============================] - 10s 347ms/step - loss: 9.0582e-04 - accuracy: 1.0000 - val_loss: 1.4802 - val_accuracy: 0.6738
# Epoch 46/100
# 29/29 [==============================] - 10s 346ms/step - loss: 8.3831e-04 - accuracy: 1.0000 - val_loss: 1.5082 - val_accuracy: 0.6609
# Epoch 47/100
# 29/29 [==============================] - 10s 346ms/step - loss: 6.0988e-04 - accuracy: 1.0000 - val_loss: 1.4868 - val_accuracy: 0.6652
# Epoch 48/100
# 29/29 [==============================] - 10s 347ms/step - loss: 6.0957e-04 - accuracy: 1.0000 - val_loss: 1.4347 - val_accuracy: 0.6867
# Epoch 49/100
# 29/29 [==============================] - 10s 346ms/step - loss: 4.7261e-04 - accuracy: 1.0000 - val_loss: 1.4196 - val_accuracy: 0.6953
# Epoch 50/100
# 29/29 [==============================] - 10s 351ms/step - loss: 8.2416e-04 - accuracy: 1.0000 - val_loss: 1.4416 - val_accuracy: 0.6996
# Epoch 51/100
# 29/29 [==============================] - 10s 348ms/step - loss: 7.0039e-04 - accuracy: 1.0000 - val_loss: 1.4287 - val_accuracy: 0.7039
# Epoch 52/100
# 29/29 [==============================] - 10s 361ms/step - loss: 6.1815e-04 - accuracy: 1.0000 - val_loss: 1.4574 - val_accuracy: 0.6953
# Epoch 53/100
# 29/29 [==============================] - 10s 344ms/step - loss: 5.1053e-04 - accuracy: 1.0000 - val_loss: 1.4628 - val_accuracy: 0.6867
# Epoch 54/100
# 29/29 [==============================] - 10s 346ms/step - loss: 8.1113e-04 - accuracy: 1.0000 - val_loss: 1.4687 - val_accuracy: 0.6738
# Epoch 55/100
# 29/29 [==============================] - 10s 344ms/step - loss: 3.3631e-04 - accuracy: 1.0000 - val_loss: 1.4813 - val_accuracy: 0.6695
# Epoch 56/100
# 29/29 [==============================] - 10s 345ms/step - loss: 4.6376e-04 - accuracy: 1.0000 - val_loss: 1.6203 - val_accuracy: 0.6609
# Epoch 57/100
# 29/29 [==============================] - 10s 347ms/step - loss: 3.8901e-04 - accuracy: 1.0000 - val_loss: 1.5466 - val_accuracy: 0.6609
# Epoch 58/100
# 29/29 [==============================] - 10s 350ms/step - loss: 3.3203e-04 - accuracy: 1.0000 - val_loss: 1.5418 - val_accuracy: 0.6652
# Epoch 59/100
# 29/29 [==============================] - 10s 343ms/step - loss: 3.8442e-04 - accuracy: 1.0000 - val_loss: 1.5336 - val_accuracy: 0.6738
# Epoch 60/100
# 29/29 [==============================] - 10s 343ms/step - loss: 5.1847e-04 - accuracy: 1.0000 - val_loss: 1.5765 - val_accuracy: 0.6867
# Epoch 61/100
# 29/29 [==============================] - 10s 345ms/step - loss: 2.4944e-04 - accuracy: 1.0000 - val_loss: 1.5605 - val_accuracy: 0.6824
# Epoch 62/100
# 29/29 [==============================] - 10s 347ms/step - loss: 3.8580e-04 - accuracy: 1.0000 - val_loss: 1.5422 - val_accuracy: 0.6910
# Epoch 63/100
# 29/29 [==============================] - 10s 343ms/step - loss: 2.9043e-04 - accuracy: 1.0000 - val_loss: 1.5355 - val_accuracy: 0.6781
# Epoch 64/100
# 29/29 [==============================] - 10s 345ms/step - loss: 3.3960e-04 - accuracy: 1.0000 - val_loss: 1.5364 - val_accuracy: 0.6695
# Epoch 65/100
# 29/29 [==============================] - 10s 342ms/step - loss: 2.6740e-04 - accuracy: 1.0000 - val_loss: 1.5438 - val_accuracy: 0.6738
# Epoch 66/100
# 29/29 [==============================] - 10s 347ms/step - loss: 2.4444e-04 - accuracy: 1.0000 - val_loss: 1.5491 - val_accuracy: 0.6695
# Epoch 67/100
# 29/29 [==============================] - 10s 345ms/step - loss: 2.7730e-04 - accuracy: 1.0000 - val_loss: 1.5617 - val_accuracy: 0.6695
# Epoch 68/100
# 29/29 [==============================] - 10s 348ms/step - loss: 2.4497e-04 - accuracy: 1.0000 - val_loss: 1.5530 - val_accuracy: 0.6824
# Epoch 69/100
# 29/29 [==============================] - 10s 342ms/step - loss: 2.0043e-04 - accuracy: 1.0000 - val_loss: 1.5652 - val_accuracy: 0.6781
# Epoch 70/100
# 29/29 [==============================] - 10s 345ms/step - loss: 3.3479e-04 - accuracy: 1.0000 - val_loss: 1.5943 - val_accuracy: 0.6652
# Epoch 71/100
# 29/29 [==============================] - 10s 343ms/step - loss: 1.5541e-04 - accuracy: 1.0000 - val_loss: 1.6016 - val_accuracy: 0.6609
# Epoch 72/100
# 29/29 [==============================] - 10s 355ms/step - loss: 2.3913e-04 - accuracy: 1.0000 - val_loss: 1.5699 - val_accuracy: 0.6695
# Epoch 73/100
# 29/29 [==============================] - 10s 350ms/step - loss: 1.3787e-04 - accuracy: 1.0000 - val_loss: 1.5655 - val_accuracy: 0.6695
# Epoch 74/100
# 29/29 [==============================] - 10s 354ms/step - loss: 2.0418e-04 - accuracy: 1.0000 - val_loss: 1.6002 - val_accuracy: 0.6695
# Epoch 75/100
# 29/29 [==============================] - 10s 348ms/step - loss: 2.1236e-04 - accuracy: 1.0000 - val_loss: 1.5997 - val_accuracy: 0.6609
# Epoch 76/100
# 29/29 [==============================] - 10s 348ms/step - loss: 1.1916e-04 - accuracy: 1.0000 - val_loss: 1.5906 - val_accuracy: 0.6609
# Epoch 77/100
# 29/29 [==============================] - 10s 346ms/step - loss: 1.2248e-04 - accuracy: 1.0000 - val_loss: 1.6011 - val_accuracy: 0.6609
# Epoch 78/100
# 29/29 [==============================] - 10s 344ms/step - loss: 1.7841e-04 - accuracy: 1.0000 - val_loss: 1.5867 - val_accuracy: 0.6652
# Epoch 79/100
# 29/29 [==============================] - 10s 343ms/step - loss: 2.0039e-04 - accuracy: 1.0000 - val_loss: 1.5714 - val_accuracy: 0.6695
# Epoch 80/100
# 29/29 [==============================] - 10s 345ms/step - loss: 2.1096e-04 - accuracy: 1.0000 - val_loss: 1.5595 - val_accuracy: 0.6695
# Epoch 81/100
# 29/29 [==============================] - 10s 343ms/step - loss: 2.0741e-04 - accuracy: 1.0000 - val_loss: 1.5810 - val_accuracy: 0.6652
# Epoch 82/100
# 29/29 [==============================] - 10s 349ms/step - loss: 1.1587e-04 - accuracy: 1.0000 - val_loss: 1.5745 - val_accuracy: 0.6695
# Epoch 83/100
# 29/29 [==============================] - 10s 344ms/step - loss: 2.1176e-04 - accuracy: 1.0000 - val_loss: 1.5784 - val_accuracy: 0.6652
# Epoch 84/100
# 29/29 [==============================] - 10s 343ms/step - loss: 1.4644e-04 - accuracy: 1.0000 - val_loss: 1.5745 - val_accuracy: 0.6609
# Epoch 85/100
# 29/29 [==============================] - 10s 345ms/step - loss: 1.4641e-04 - accuracy: 1.0000 - val_loss: 1.6120 - val_accuracy: 0.6738
# Epoch 86/100
# 29/29 [==============================] - 10s 347ms/step - loss: 9.5003e-05 - accuracy: 1.0000 - val_loss: 1.6063 - val_accuracy: 0.6781
# Epoch 87/100
# 29/29 [==============================] - 10s 346ms/step - loss: 2.1409e-04 - accuracy: 1.0000 - val_loss: 1.5900 - val_accuracy: 0.6781
# Epoch 88/100
# 29/29 [==============================] - 10s 352ms/step - loss: 8.9353e-05 - accuracy: 1.0000 - val_loss: 1.5871 - val_accuracy: 0.6824
# Epoch 89/100
# 29/29 [==============================] - 10s 345ms/step - loss: 1.1101e-04 - accuracy: 1.0000 - val_loss: 1.5975 - val_accuracy: 0.6695
# Epoch 90/100
# 29/29 [==============================] - 10s 346ms/step - loss: 1.4081e-04 - accuracy: 1.0000 - val_loss: 1.6112 - val_accuracy: 0.6609
# Epoch 91/100
# 29/29 [==============================] - 10s 344ms/step - loss: 1.3272e-04 - accuracy: 1.0000 - val_loss: 1.6585 - val_accuracy: 0.6567
# Epoch 92/100
# 29/29 [==============================] - 10s 344ms/step - loss: 1.0557e-04 - accuracy: 1.0000 - val_loss: 1.6405 - val_accuracy: 0.6567
# Epoch 93/100
# 29/29 [==============================] - 10s 343ms/step - loss: 1.2420e-04 - accuracy: 1.0000 - val_loss: 1.6296 - val_accuracy: 0.6695
# Epoch 94/100
# 29/29 [==============================] - 10s 344ms/step - loss: 9.6845e-05 - accuracy: 1.0000 - val_loss: 1.6212 - val_accuracy: 0.6609
# Epoch 95/100
# 29/29 [==============================] - 10s 344ms/step - loss: 1.0532e-04 - accuracy: 1.0000 - val_loss: 1.5971 - val_accuracy: 0.6652
# Epoch 96/100
# 29/29 [==============================] - 10s 344ms/step - loss: 1.1515e-04 - accuracy: 1.0000 - val_loss: 1.5897 - val_accuracy: 0.6609
# Epoch 97/100
# 29/29 [==============================] - 10s 346ms/step - loss: 8.9091e-05 - accuracy: 1.0000 - val_loss: 1.5975 - val_accuracy: 0.6609
# Epoch 98/100
# 29/29 [==============================] - 10s 351ms/step - loss: 1.5027e-04 - accuracy: 1.0000 - val_loss: 1.6277 - val_accuracy: 0.6695
# Epoch 99/100
# 29/29 [==============================] - 10s 343ms/step - loss: 1.0880e-04 - accuracy: 1.0000 - val_loss: 1.6293 - val_accuracy: 0.6695
# Epoch 100/100
# 29/29 [==============================] - 10s 343ms/step - loss: 1.2535e-04 - accuracy: 1.0000 - val_loss: 1.5997 - val_accuracy: 0.6738

# %%
loss, acc = model.evaluate(images, labels)
print("Train, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 37/37 [==============================] - 2s 47ms/step - loss: 0.3211 - accuracy: 0.9345
# Train, accuracy: 93.45%

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.ylabel('accuracy/loss')
plt.xlabel('epoch')
plt.gca().set_ylim(0, 3.5)
plt.show()

# %% [markdown]
# ## Save Modell

# %%
model.save_weights("kr_model.h5")

# %% [markdown]
# ## Test Modell

# %%
PATH_RAVDESS_TEST = PATH_TO_RAVDESS/"test"
bs_test = 1440

# %%
ravdess_test = PrecomputedRavdess(PATH_RAVDESS_TEST,
                                  img_transforms=transforms.Compose([
                                      transforms.ToTensor(),
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                          std=[0.229, 0.224, 0.225])])
)
ravdess_test_loader = torch.utils.data.DataLoader(ravdess_test,bs_test, shuffle=True)
images_test, labels_test = next(iter(ravdess_test_loader))

# %%
labels_test.shape
# Out:
# torch.Size([279])

# %%
images_test = (tf.cast(images_test, tf.float32) / 255).numpy()
labels_test = labels_test.numpy()

# %%
model_test = keras.models.Sequential()
model_test.add(DefaultConv2D(64, kernel_size=3, strides=1,
                        input_shape= input_shape ))
model_test.add(keras.layers.BatchNormalization())
model_test.add(keras.layers.Activation("relu"))
model_test.add(keras.layers.MaxPool2D(pool_size=3, strides=2, padding="SAME"))
prev_filters = 8
for filters in [64] * 1 + [128] * 1 + [256] * 2: 
    strides = 1 if filters == prev_filters else 2
    model_test.add(ResidualUnit(filters, strides=strides))
    prev_filters = filters
model_test.add(keras.layers.GlobalAvgPool2D())
model_test.add(keras.layers.Flatten())
model_test.add(keras.layers.Dense(no_classes, activation="softmax"))

# %%
model_test.load_weights('kr_model.h5')

# %%
optimizer = keras.optimizers.Nadam(lr=1e-3)
model_test.compile(loss=loss_function,
              optimizer=optimizer,  metrics=['accuracy'])

# %%
loss, acc = model.evaluate(images_test, labels_test)
print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))
# Out:
# 9/9 [==============================] - 0s 45ms/step - loss: 1.6093 - accuracy: 0.6953
# Restored model, accuracy: 69.53%

# %%
model_test.save_weights("kr_model_prod.h5")
