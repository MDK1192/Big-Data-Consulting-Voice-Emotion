# %%
import torch
import torch.nn.functional as F
import torchvision.models as models

# %%
device="cpu"
models_ensemble = [models.resnet18().to(device), models.resnet34().to(device)]
predictions = [F.softmax(m(torch.rand(1,3,224,244).to(device))) for m in models_ensemble] 
avg_prediction = torch.stack(predictions).mean(0).argmax()
# Out:
# <ipython-input-6-30e2b1d0d2a0>:3: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   predictions = [F.softmax(m(torch.rand(1,3,224,244).to(device))) for m in models_ensemble]

# %%
avg_prediction
# Out:
# tensor(974)

# %%
torch.stack(predictions)
# Out:
# tensor([[[0.0014, 0.0004, 0.0009,  ..., 0.0016, 0.0007, 0.0003]],
#
#         [[0.0009, 0.0011, 0.0006,  ..., 0.0004, 0.0003, 0.0013]]],
#        grad_fn=<StackBackward>)
